# %%
from elasticsearch import Elasticsearch
from elasticsearch.helpers import scan
import pandas as pd

#es = Elasticsearch(host='localhost', port=9200)

es = Elasticsearch(
    cloud_id="WHS:YXVzdHJhbGlhLXNvdXRoZWFzdDEuZ2NwLmVsYXN0aWMtY2xvdWQuY29tJGNhYTExYzViNzQ3YjQwMzViZWFhNzQ1MTcwY2EwOWZlJDZkOWQxNzg1ZjM1MDQxMDdhOTcxMWYyMWU5YjE3ZmQx",
    basic_auth=("elastic", "BnV9bouQp2Pbksh0Zla8Ow78")
)

def get_data_from_elastic(index_name):
    # query: The elasticsearch query.
    #query = {
    #    "query": {
    #        "match": {
    #            "author": "Emma Roth"
    #        }
    #    }
    #}

    # Scan function to get all the data. 
    rel = scan(client=es,             
               #query=query,                                     
               scroll='1m',
               index=index_name,
               raise_on_error=True,
               preserve_order=False,
               clear_scroll=True)

    # Keep response in a list.
    result = list(rel)

    temp = []

    # We need only '_source', which has all the fields required.
    # This elimantes the elasticsearch metdata like _id, _type, _index.
    for hit in result:
        temp.append(hit['_source'])

    # Create a dataframe.
    df = pd.DataFrame(temp)

    return df

# %% [markdown]
# Fetch pubmed data from Elastic
# Index Name - search-pubmed_index_whs

# %%
df_pubmed = get_data_from_elastic("search-pubmed_index_whs")

df_pubmed
# Out:
#           last_crawled_at                                    additional_urls  \
# 0    2022-10-09T04:08:42Z        [https://pubmed.ncbi.nlm.nih.gov/23447071/]
# 1    2022-10-09T04:08:42Z        [https://pubmed.ncbi.nlm.nih.gov/28816192/]
# 2    2022-10-09T04:08:42Z        [https://pubmed.ncbi.nlm.nih.gov/30124695/]
# 3    2022-10-09T04:08:42Z        [https://pubmed.ncbi.nlm.nih.gov/32447897/]
# 4    2022-10-09T04:08:42Z        [https://pubmed.ncbi.nlm.nih.gov/36031258/]
# ..                    ...                                                ...
# 995  2022-10-09T04:11:47Z  [https://pubmed.ncbi.nlm.nih.gov/clinical/?ter...
# 996  2022-10-09T04:11:47Z  [https://pubmed.ncbi.nlm.nih.gov/clinical/?ter...
# 997  2022-10-09T04:11:47Z  [https://pubmed.ncbi.nlm.nih.gov/clinical/?ter...
# 998  2022-10-09T04:11:47Z  [https://pubmed.ncbi.nlm.nih.gov/clinical/?ter...
# 999  2022-10-09T04:11:47Z  [https://pubmed.ncbi.nlm.nih.gov/clinical/?ter...
#
#                                           body_content  \
# 0    Harmful drinking and experiences of alcohol-re...
# 1    Tobacco Abuse and Associated Oral Lesions amon...
# 2    Toward sustainable and systematic recycling of...
# 3    [Application of risk assessment of dust occupa...
# 4    Occupational injuries among non-standard worke...
# ..                                                 ...
# 995  This site needs JavaScript to work properly. P...
# 996  This site needs JavaScript to work properly. P...
# 997  This site needs JavaScript to work properly. P...
# 998  This site needs JavaScript to work properly. P...
# 999  This site needs JavaScript to work properly. P...
#
#                                domains  \
# 0    [https://pubmed.ncbi.nlm.nih.gov]
# 1    [https://pubmed.ncbi.nlm.nih.gov]
# 2    [https://pubmed.ncbi.nlm.nih.gov]
# 3    [https://pubmed.ncbi.nlm.nih.gov]
# 4    [https://pubmed.ncbi.nlm.nih.gov]
# ..                                 ...
# 995  [https://pubmed.ncbi.nlm.nih.gov]
# 996  [https://pubmed.ncbi.nlm.nih.gov]
# 997  [https://pubmed.ncbi.nlm.nih.gov]
# 998  [https://pubmed.ncbi.nlm.nih.gov]
# 999  [https://pubmed.ncbi.nlm.nih.gov]
#
#                                                  title  \
# 0    Harmful drinking and experiences of alcohol-re...
# 1    Tobacco Abuse and Associated Oral Lesions amon...
# 2    Toward sustainable and systematic recycling of...
# 3    [Application of risk assessment of dust occupa...
# 4    Occupational injuries among non-standard worke...
# ..                                                 ...
# 995                          Clinical Queries - PubMed
# 996                          Clinical Queries - PubMed
# 997                          Clinical Queries - PubMed
# 998                          Clinical Queries - PubMed
# 999                          Clinical Queries - PubMed
#
#                                          meta_keywords  \
# 0    pmid:23447071, doi:10.1177/1557988313479965, K...
# 1    pmid:28816192, doi:10.5005/jp-journals-10024-2...
# 2    pmid:30124695, doi:10.1039/c8cs00297e, Review,...
# 3    pmid:32447897, doi:10.3760/cma.j.cn121094-2019...
# 4    pmid:36031258, doi:10.1016/j.jsr.2022.06.006, ...
# ..                                                 ...
# 995                                                NaN
# 996                                                NaN
# 997                                                NaN
# 998                                                NaN
# 999                                                NaN
#
#                                                    url url_scheme  \
# 0            https://pubmed.ncbi.nlm.nih.gov/23447071/      https
# 1            https://pubmed.ncbi.nlm.nih.gov/28816192/      https
# 2            https://pubmed.ncbi.nlm.nih.gov/30124695/      https
# 3            https://pubmed.ncbi.nlm.nih.gov/32447897/      https
# 4            https://pubmed.ncbi.nlm.nih.gov/36031258/      https
# ..                                                 ...        ...
# 995  https://pubmed.ncbi.nlm.nih.gov/clinical/?term...      https
# 996  https://pubmed.ncbi.nlm.nih.gov/clinical/?term...      https
# 997  https://pubmed.ncbi.nlm.nih.gov/clinical/?term...      https
# 998  https://pubmed.ncbi.nlm.nih.gov/clinical/?term...      https
# 999  https://pubmed.ncbi.nlm.nih.gov/clinical/?term...      https
#
#                                       meta_description  \
# 0    This study sought to understand the prevalence...
# 1    Building workers are unprotected from various ...
# 2    Ever-growing global energy needs and environme...
# 3    <span><b>Objective:</b> To identify the proces...
# 4    The results can be used to establish effective...
# ..                                                 ...
# 995                          Clinical Queries - PubMed
# 996                          Clinical Queries - PubMed
# 997                          Clinical Queries - PubMed
# 998                          Clinical Queries - PubMed
# 999                          Clinical Queries - PubMed
#
#                                               headings  \
# 0    [Harmful drinking and experiences of alcohol-r...
# 1    [Tobacco Abuse and Associated Oral Lesions amo...
# 2    [Toward sustainable and systematic recycling o...
# 3    [[Application of risk assessment of dust occup...
# 4    [Occupational injuries among non-standard work...
# ..                                                 ...
# 995  [Account, PubMed Clinical Queries, Results for...
# 996  [Account, PubMed Clinical Queries, Results for...
# 997  [Account, PubMed Clinical Queries, Results for...
# 998  [Account, PubMed Clinical Queries, Results for...
# 999  [Account, PubMed Clinical Queries, Results for...
#
#                                                  links  \
# 0    [http://pubmed.ncbi.nlm.nih.gov/23447071/, htt...
# 1    [http://pubmed.ncbi.nlm.nih.gov/28816192/, htt...
# 2    [http://pubmed.ncbi.nlm.nih.gov/30124695/, htt...
# 3    [http://pubmed.ncbi.nlm.nih.gov/32447897/, htt...
# 4    [http://pubmed.ncbi.nlm.nih.gov/36031258/, htt...
# ..                                                 ...
# 995  [https://account.ncbi.nlm.nih.gov, https://pub...
# 996  [https://account.ncbi.nlm.nih.gov, https://pub...
# 997  [https://account.ncbi.nlm.nih.gov, https://pub...
# 998  [https://account.ncbi.nlm.nih.gov, https://pub...
# 999  [https://account.ncbi.nlm.nih.gov, https://pub...
#
#                            id  url_port                 url_host    url_path  \
# 0    634247f1181ef5ed3a932801       443  pubmed.ncbi.nlm.nih.gov  /23447071/
# 1    634247f5181ef54149932be0       443  pubmed.ncbi.nlm.nih.gov  /28816192/
# 2    634246d9181ef504a192a074       443  pubmed.ncbi.nlm.nih.gov  /30124695/
# 3    6342494a181ef5619d93b6d3       443  pubmed.ncbi.nlm.nih.gov  /32447897/
# 4    6342494a181ef5fe7a93b6f3       443  pubmed.ncbi.nlm.nih.gov  /36031258/
# ..                        ...       ...                      ...         ...
# 995  6342478d181ef5b21f9322bd       443  pubmed.ncbi.nlm.nih.gov  /clinical/
# 996  6342478d181ef5ecc29322d0       443  pubmed.ncbi.nlm.nih.gov  /clinical/
# 997  6342478d181ef5943c9322cb       443  pubmed.ncbi.nlm.nih.gov  /clinical/
# 998  6342478f181ef50ae4932477       443  pubmed.ncbi.nlm.nih.gov  /clinical/
# 999  6342478f181ef515c0932471       443  pubmed.ncbi.nlm.nih.gov  /clinical/
#
#     url_path_dir1
# 0        23447071
# 1        28816192
# 2        30124695
# 3        32447897
# 4        36031258
# ..            ...
# 995      clinical
# 996      clinical
# 997      clinical
# 998      clinical
# 999      clinical
#
# [1000 rows x 16 columns]

# %% [markdown]
# Fetch News Data from Elastic
# Index Name - search-index-whs-news

# %%
df_news = get_data_from_elastic("search-index-whs-news")

df_news
# Out:
#      column1           publishedAt                                author  \
# 0          0  2022-10-08T13:47:56Z                             Emma Roth
# 1          1  2022-09-12T16:11:00Z                                   NaN
# 2          2  2022-10-05T10:04:00Z                                   NaN
# 3          3  2022-09-12T13:19:00Z                                   NaN
# 4          4  2022-10-03T14:16:00Z                                   NaN
# ..       ...                   ...                                   ...
# 142       42  2022-09-21T16:30:14Z                    Brandon Vigliarolo
# 143       43  2022-10-07T11:37:00Z                                   NaN
# 144       44  2022-10-07T16:49:23Z  Alana Mastrangelo, Alana Mastrangelo
# 145       45  2022-09-27T23:18:01Z                       Motorcycle News
# 146       46  2022-10-06T05:00:00Z                        Marília Matoso
#
#                                             urlToImage  \
# 0    https://cdn.vox-cdn.com/thumbor/BsEQvlTIPpdzeU...
# 1    https://www.reuters.com/resizer/GB6noncFXwEA1H...
# 2    https://www.reuters.com/resizer/PN5yOqnqEIMLDz...
# 3    https://www.reuters.com/pf/resources/images/re...
# 4    https://www.reuters.com/resizer/3-KTDd7LS1AEax...
# ..                                                 ...
# 142  https://regmedia.co.uk/2021/08/03/handout_tesl...
# 143  https://mma.prnewswire.com/media/1885554/cisio...
# 144  https://media.breitbart.com/media/2022/10/Flor...
# 145  https://www.mcnews.com.au/wp-content/uploads/2...
# 146  https://images.adsttc.com/media/images/62f2/cd...
#
#                                            description       source_id  \
# 0    Rivian recalled around 13,000 electric vehicle...       the-verge
# 1    Still-young electric-vehicle startups already ...         reuters
# 2    In a February meeting with mining executives, ...         reuters
# 3    The London Metal Exchange's (LME) controversia...         reuters
# 4    More than half a century after gangrene claime...         reuters
# ..                                                 ...             ...
# 142  It's better to burn out than to fade away A Te...             NaN
# 143  A roundup of the week's most newsworthy auto a...             NaN
# 144  Electric vehicles have caught on fire in Flori...  breitbart-news
# 145  Motorcycle Recall Notices GASGAS MC250 Motorcy...             NaN
# 146  The era of petrol cars is coming to an end wit...             NaN
#
#                                                  title  \
# 0    Rivian recalls 13,000 EVs over loose fastener ...
# 1                        SPACs’ long shadows - Reuters
# 2    U.S. steps away from flagship lithium project ...
# 3    Column: Shanghai's nickel twist risks more mar...
# 4    Ukrainian pensioner who lost legs defies Russi...
# ..                                                 ...
# 142  Tesla Megapack battery ignites at substation a...
# 143  This Week in Transportation News: 10 Stories Y...
# 144  Florida Officials: Hurricane Ian Has Turned El...
# 145  Recall Round Up: GASGAS, Honda, Yamaha, BMW & ...
# 146  Gas Stations and Electric Cars: How Do They Ch...
#
#                                                    url  \
# 0    https://www.theverge.com/2022/10/8/23393948/ri...
# 1    https://www.reuters.com/breakingviews/spacs-lo...
# 2    https://www.reuters.com/markets/us/us-steps-aw...
# 3    https://www.reuters.com/markets/commodities/sh...
# 4    https://www.reuters.com/world/europe/ukrainian...
# ..                                                 ...
# 142  https://www.theregister.com/2022/09/21/tesla_b...
# 143  https://www.prnewswire.com/news-releases/this-...
# 144  https://www.breitbart.com/tech/2022/10/07/flor...
# 145  https://www.mcnews.com.au/recall-round-up-gasg...
# 146  https://www.archdaily.com/989627/gas-stations-...
#
#                                                content      source_name
# 0    Rivian recalls 13,000 EVs over loose fastener ...        The Verge
# 1    NEW YORK, Sept 12 (Reuters Breakingviews) - St...          Reuters
# 2    Oct 5 (Reuters) - In a February meeting with m...          Reuters
# 3    LONDON, Sept 12 (Reuters) - The London Metal E...          Reuters
# 4    ZAPORIZHZHIA, Ukraine, Oct 3 (Reuters) - More ...          Reuters
# ..                                                 ...              ...
# 142  A Tesla Megapack battery at a California subst...  Theregister.com
# 143  A roundup of the week's most newsworthy auto a...       PRNewswire
# 144  Electric vehicles have caught on fire in Flori...   Breitbart News
# 145  Motorcycle Recall Notices\r\nGASGAS MC250 Moto...    Mcnews.com.au
# 146  Photo by Kyle Bushnell, via Unsplash\r\nThe er...        ArchDaily
#
# [147 rows x 10 columns]
